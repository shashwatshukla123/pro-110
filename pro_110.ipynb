# %% [markdown]
# <a href="https://colab.research.google.com/github/shashwatshukla123/pro-110/blob/main/pro_110.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly.figure_factory as ff
import statistics
import random
import pandas as pd
import csv

# %%
df = pd.read_csv("data.csv")
data = df["temp"].tolist()

print("Mean of whole data:- ",statistics.mean(data))
print("Standard deviation of whole data:- ",statistics.stdev(data))
# Out:
# Mean of whole data:-  35.05393111079237
# Standard deviation of whole data:-  5.699825337585306

# %%
def random_set_of_mean(counter):
    dataset = []
    for i in range(0, counter):
        random_index= random.randint(0,len(data))
        value = data[random_index]
        dataset.append(value)
    mean2 = statistics.mean(dataset)
    return mean2

# %%
def setup():
    mean_list = []
    for i in range(0,100):
        set_of_means= random_set_of_mean(30)
        mean_list.append(set_of_means)
    show_fig(mean_list)
    
setup()

def show_fig(mean_list):
    df = mean_list
    fig = ff.create_distplot([df], ["temp"], show_hist=False)
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="dad963e9-c367-4ad4-a73f-4250142cf9e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dad963e9-c367-4ad4-a73f-4250142cf9e9")) {
#                     Plotly.newPlot(
#                         'dad963e9-c367-4ad4-a73f-4250142cf9e9',
#                         [{"legendgroup": "temp", "marker": {"color": "rgb(31, 119, 180)"}, "mode": "lines", "name": "temp", "showlegend": true, "type": "scatter", "x": [32.9, 32.91, 32.92, 32.93, 32.94, 32.949999999999996, 32.96, 32.97, 32.98, 32.99, 33.0, 33.01, 33.019999999999996, 33.03, 33.04, 33.05, 33.059999999999995, 33.07, 33.08, 33.089999999999996, 33.1, 33.11, 33.12, 33.129999999999995, 33.14, 33.15, 33.16, 33.17, 33.18, 33.19, 33.199999999999996, 33.21, 33.22, 33.23, 33.24, 33.25, 33.26, 33.269999999999996, 33.28, 33.29, 33.3, 33.309999999999995, 33.32, 33.33, 33.339999999999996, 33.35, 33.36, 33.37, 33.379999999999995, 33.39, 33.4, 33.41, 33.42, 33.43, 33.44, 33.449999999999996, 33.46, 33.47, 33.48, 33.49, 33.5, 33.51, 33.519999999999996, 33.53, 33.54, 33.55, 33.559999999999995, 33.57, 33.58, 33.589999999999996, 33.6, 33.61, 33.62, 33.629999999999995, 33.64, 33.65, 33.66, 33.67, 33.68, 33.69, 33.699999999999996, 33.71, 33.72, 33.73, 33.74, 33.75, 33.76, 33.769999999999996, 33.78, 33.79, 33.8, 33.809999999999995, 33.82, 33.83, 33.839999999999996, 33.85, 33.86, 33.87, 33.879999999999995, 33.89, 33.9, 33.91, 33.92, 33.93, 33.94, 33.949999999999996, 33.96, 33.97, 33.98, 33.99, 34.0, 34.01, 34.019999999999996, 34.03, 34.04, 34.05, 34.059999999999995, 34.07, 34.08, 34.089999999999996, 34.1, 34.11, 34.12, 34.129999999999995, 34.14, 34.15, 34.16, 34.17, 34.18, 34.19, 34.199999999999996, 34.21, 34.22, 34.23, 34.24, 34.25, 34.26, 34.269999999999996, 34.28, 34.29, 34.3, 34.309999999999995, 34.32, 34.33, 34.339999999999996, 34.35, 34.36, 34.37, 34.379999999999